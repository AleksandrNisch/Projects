# %%
import numpy as np
count = 0                            # счетчик попыток
number = np.random.randint(1,101)    # загадали число
print ("Загадано число от 1 до 100","\n")


def game_core_v3(number):
    '''решаем методом бинарного поиска'''  
    count = 0
    limit_min = 0
    limit_max = 100
    predict = (limit_min + limit_max)//2 #Задали середину интервала
    
    while predict != number:
        count+=1
        print ('count', count) # для проверки хода решения печатаем счетчик
        print ('number', number) # для оценки процесса поиска печатаем само число
        predict = (limit_min + limit_max)//2
        
        if number > predict: 
            limit_min = (limit_min + limit_max)//2 + 1
            print('limit_min', limit_min,"\n") # для проверки хода решения печатаем новую нижнюю границу поиска
            
        elif number < predict:            
            limit_max = (limit_min + limit_max)//2 - 1
            print('limit_max', limit_max,"\n") # для проверки хода решения печатаем новую верхнюю границу поиска        
            
    return(count) # выход из цикла, если угадали
        
        
def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

# Проверяем
score_game(game_core_v3)
# Out:
# Загадано число от 1 до 100
#
# count 1
# number 38
# limit_max 49
#
# count 2
# number 38
# limit_min 25
#
# count 3
# number 38
# limit_min 38
#
# count 4
# number 38
# limit_max 42
#
# count 5
# number 38
# limit_max 39
#
# count 6
# number 38
# count 1
# number 13
# limit_max 49
#
# count 2
# number 13
# limit_max 23
#
# count 3
# number 13
# limit_min 12
#
# count 4
# number 13
# limit_max 16
#
# count 5
# number 13
# limit_max 13
#
# count 6
# number 13
# limit_min 13
#
# count 7
# number 13
# count 1
# number 73
# limit_min 51
#
# count 2
# number 73
# limit_max 74
#
# count 3
# number 73
# limit_min 63
#
# count 4
# number 73
# limit_min 69
#
# count 5
# number 73
# limit_min 72
#
# count 6
# number 73
# count 1
# number 10
# limit_max 49
#
# count 2
# number 10
# limit_max 23
#
# count 3
# number 10
# limit_max 10
#
# count 4
# number 10
# limit_min 6
#
# count 5
# number 10
# limit_min 9
#
# count 6
# number 10
# limit_min 10
#
# count 7
# number 10
# count 1
# number 76
# ...
